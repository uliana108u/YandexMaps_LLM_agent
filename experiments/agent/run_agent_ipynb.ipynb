# %% [markdown]
# # notebook run_agent_ipynb.ipynb
# Тетрадка для запуска агента

# %%
import sys
import os

# Добавляем корень проекта в sys.path (на два уровня выше)
CURRENT_DIR = os.path.dirname(os.path.abspath(""))
BASE_DIR = os.path.abspath(os.path.join(CURRENT_DIR, ".."))
if BASE_DIR not in sys.path:
    sys.path.insert(0, BASE_DIR)

# %%
from main_runner import main
main(version="v1")  # тот самый какой-то агент
# Out:
# ✅ Данные загружены. Train: 29592, Val: 299, Test: 500
#
# 🚀 Запуск на валидации (версия промта: v1)...
# Agent Evaluation:   0%|          | 0/60 [00:00<?, ?it/s]
# 2025-07-08 08:12:28,568 - httpx - INFO - HTTP Request: POST https://api.vsegpt.ru/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-08 08:12:29,707 - httpx - INFO - HTTP Request: POST https://api.vsegpt.ru/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-08 08:12:30,961 - httpx - INFO - HTTP Request: POST https://api.vsegpt.ru/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-08 08:12:32,212 - httpx - INFO - HTTP Request: POST https://api.vsegpt.ru/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-08 08:12:36,419 - httpx - INFO - HTTP Request: POST https://api.vsegpt.ru/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-08 08:12:37,788 - httpx - INFO - HTTP Request: POST https://api.vsegpt.ru/v1/chat/completions "HTTP/1.1 200 OK"
# ...

# %%
f'Стоимость данного прогона в vsegpt {198+250-285} рублей'
# Out:
# 'Стоимость данного прогона в vsegpt 163 рублей'

# %%
f'Стоимость запросов в поисковик через tavily: {433}'
# Out:
# 'Стоимость запросов в поисковик через tavily: 433'

# %%
start_balance_vsegpt = 284.053940
start_balance_tavily = 433

# %%
from main_runner import main
main(version="v2")  # вторая версия
# Out:
# ✅ Данные загружены. Train: 29592, Val: 299, Test: 500
#
# 🚀 Запуск на валидации (версия промта: v2)...
# Agent Evaluation:   0%|          | 0/60 [00:00<?, ?it/s]
# 2025-07-09 12:58:41,796 - openai._base_client - INFO - Retrying request to /chat/completions in 0.488924 seconds
# 2025-07-09 12:59:15,779 - openai._base_client - INFO - Retrying request to /chat/completions in 0.481475 seconds
# 2025-07-09 12:59:55,096 - openai._base_client - INFO - Retrying request to /chat/completions in 0.416524 seconds
# 2025-07-09 13:02:34,501 - openai._base_client - INFO - Retrying request to /chat/completions in 0.418058 seconds
# 2025-07-09 13:05:43,320 - openai._base_client - INFO - Retrying request to /chat/completions in 0.417309 seconds
# 2025-07-09 13:12:27,882 - openai._base_client - INFO - Retrying request to /chat/completions in 0.438943 seconds
# 2025-07-09 13:12:28,374 - openai._base_client - INFO - Retrying request to /chat/completions in 0.933246 seconds
# ...

# %%
f'Стоимость запросов в поисковик через tavily: {904 -start_balance_tavily} credits'
# Out:
# 'Стоимость запросов в поисковик через tavily: 471 credits'

# %%
f'Стоимость услуг vsegpt: {start_balance_vsegpt - 150.412040} рублей'
# Out:
# 'Стоимость услуг vsegpt: 133.64190000000002 рублей'

# %%
start_balance_vsegpt = 393.51508
start_balance_tavily = 0

# %% [markdown]
# Случайно внесла комментарии в .txt файлы промтов и они попали модели. Неожиданно это дало прирост)

# %%
from main_runner import main
main(version="v3")  # версия 3
# Out:
# ✅ Данные загружены. Train: 29592, Val: 299, Test: 500
#
# 🚀 Запуск на валидации (версия промта: v3)...
# Agent Evaluation:   0%|          | 0/60 [00:00<?, ?it/s]
# 2025-07-12 06:06:52,381 - openai._base_client - INFO - Retrying request to /chat/completions in 0.482730 seconds
# 2025-07-12 06:06:52,933 - openai._base_client - INFO - Retrying request to /chat/completions in 0.887509 seconds
# 2025-07-12 06:13:22,435 - openai._base_client - INFO - Retrying request to /chat/completions in 0.475956 seconds
# 2025-07-12 06:13:22,972 - openai._base_client - INFO - Retrying request to /chat/completions in 0.867098 seconds
# Accuracy (по 299 валидным примерам): 0.6288
# Ошибок обработки: 0
# Поиск использован в 183 из 299 случаев (61.2%)
# ✅ Validation accuracy: 0.6288
#
# 🚀 Запуск на тесте (версия промта: v3)...
# Agent Evaluation:   0%|          | 0/100 [00:00<?, ?it/s]
# 2025-07-12 06:16:21,801 - openai._base_client - INFO - Retrying request to /chat/completions in 0.454331 seconds
# ...

# %%
f'Стоимость услуг vsegpt: {start_balance_vsegpt - 254.345920} рублей'
# Out:
# 'Стоимость услуг vsegpt: 139.16916 рублей'

# %%
f'Стоимость запросов в поисковик через tavily: {70 - start_balance_tavily}'
# Out:
# 'Стоимость запросов в поисковик через tavily: 70'

# %%
start_balance_vsegpt = 226.173760

# %% [markdown]
# Версия, где не меняется промт need_search - такой же, как у первого агента

# %%
from main_runner import main
main(version="v3")  # версия 3
# Out:
# ✅ Данные загружены. Train: 29592, Val: 299, Test: 500
#
# 🚀 Запуск на валидации (версия промта: v3)...
# Agent Evaluation:   0%|          | 0/60 [00:00<?, ?it/s]
# 2025-07-13 09:14:23,565 - openai._base_client - INFO - Retrying request to /chat/completions in 0.380030 seconds
# 2025-07-13 09:14:47,420 - openai._base_client - INFO - Retrying request to /chat/completions in 0.424116 seconds
# 2025-07-13 09:15:31,675 - openai._base_client - INFO - Retrying request to /chat/completions in 0.385556 seconds
# 2025-07-13 09:15:39,468 - openai._base_client - INFO - Retrying request to /chat/completions in 0.380575 seconds
# 2025-07-13 09:15:39,930 - openai._base_client - INFO - Retrying request to /chat/completions in 0.772955 seconds
# 2025-07-13 09:16:34,341 - openai._base_client - INFO - Retrying request to /chat/completions in 0.473678 seconds
# 2025-07-13 09:17:37,247 - openai._base_client - INFO - Retrying request to /chat/completions in 0.429299 seconds
# ...

# %%
f'Стоимость услуг vsegpt: {start_balance_vsegpt - 91.702560} рублей'
# Out:
# 'Стоимость услуг vsegpt: 134.47119999999998 рублей'
